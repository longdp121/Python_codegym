# %%
import turtle
import math
pen = turtle.Turtle()
pen.speed(10)
pen.pensize(3)
pen.penup()
pen.goto(-200,-120) #begin point
pen.pendown()
#frontside of the house
pen.fillcolor("#60EA6E")
pen.begin_fill()
for i in range(2):
    pen.forward(150)
    pen.left(90)
    pen.forward(200)
    pen.left(90)
pen.end_fill()
#end of frontside
#door
pen.forward(90)
pen.left(90)
pen.fillcolor("#E89E3D")
pen.begin_fill()
for i in range(2):
    pen.forward(50)
    pen.left(90)
    pen.forward(30)
    pen.left(90)
pen.end_fill()
#end of the main door
#sideface of the house
pen.right(90)
pen.forward(60)
pen.left(30)
pen.fillcolor("#9A1837")
pen.begin_fill()
ac_ang = 60 #Góc nhọn
obt_ang = 180 - ac_ang #Góc tù
for i in range(3):    
    pen.forward(90)
    pen.left(ac_ang)
    pen.forward(200)
    pen.left(obt_ang)
pen.end_fill()
#roof
#roof
pen.forward(90)
pen.right(30)
pen.fillcolor("#41FAE2")
pen.begin_fill()
for i in range(3):
    pen.forward(150)
    pen.right(120)
pen.end_fill()
#end roof

#roof faceside
pen.right(60)
pen.forward(150)
pen.fillcolor("#E4E30E")
pen.begin_fill()
for i in range(2):
    pen.right(90)
    pen.forward(90)
    pen.right(90)
    pen.forward(150)
pen.end_fill()
#end roof facesize

#window
pen.backward(150)
pen.left(150)
pen.penup()
pen.forward(85)
pen.left(120)
pen.forward(30)
pen.pendown()
pen.fillcolor("pink")
pen.begin_fill()
pen.right(120)
for i in range(2):
    pen.forward(30)
    pen.left(120)
    pen.forward(30)
    pen.left(60)
pen.end_fill()
#end window

###tree
#body
pen.penup()
pen.goto(195,-240)
pen.pendown()
pen.right(180)
tall = 160
wide = tall/10
pen.fillcolor("#81480C")
pen.begin_fill()
for i in range(2):
    pen.forward(tall)
    pen.right(90)
    pen.forward(wide)
    pen.right(90)
pen.end_fill()
###
#leaf
pen.forward(tall)
pen.right(90)
pen.forward(wide/2)
pen.left(90)
pen.fillcolor("#49EB01")
pen.begin_fill()
h = tall/2
for i in range(3):
    pen.penup()
    pen.forward(h)
    pen.pendown()
    pen.left(135)
    pen.forward(h * math.sqrt(2))
    pen.left(135)
    pen.forward(2*h)
    pen.left(135)
    pen.forward(h * math.sqrt(2))
    pen.right(45)
pen.end_fill()
#end tree
#sun
#sun
ssize = 40 #sun size
lr = ssize*2/3
sr = lr*2/3
pen.penup()
pen.goto(180,220)#sun begin here
pen.pendown()
pen.fillcolor("#F95903")
pen.begin_fill()
pen.circle(ssize)
pen.end_fill()
for i in range(4):#sunray
    pen.right(90)
    pen.forward(lr)#long sunray
    pen.backward(lr)
    pen.left(90)
    pen.circle(ssize,45)#draw 1/8 of circle each time
    pen.right(90)
    pen.forward(sr)#short sunray
    pen.backward(sr)
    pen.left(90)
    pen.circle(ssize,45)
#end sun
#turtle.done()
#end of sideface
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10244/3934647984.py in <module>
#      38 obt_ang = 180 - ac_ang #Góc tù
#      39 for i in range(3):
# ---> 40     pen.forward(90)
#      41     pen.left(ac_ang)
#      42     pen.forward(200)
#
# c:\users\acer\appdata\local\programs\python\python39\lib\turtle.py in forward(self, distance)
#    1636         (-50.00,0.00)
#    1637         """
# -> 1638         self._go(distance)
#    1639
#    1640     def back(self, distance):
#
# c:\users\acer\appdata\local\programs\python\python39\lib\turtle.py in _go(self, distance)
#    1604         """move turtle forward by specified distance"""
#    1605         ende = self._position + self._orient * distance
# -> 1606         self._goto(ende)
#    1607
#    1608     def _rotate(self, angle):
#
# c:\users\acer\appdata\local\programs\python\python39\lib\turtle.py in _goto(self, end)
#    3157                       (self.currentLineItem,
#    3158                       self.currentLine[:],
# -> 3159                       screen._pointlist(self.currentLineItem),
#    3160                       self.items[:])
#    3161                       )
#
# c:\users\acer\appdata\local\programs\python\python39\lib\turtle.py in _pointlist(self, item)
#     752         (9.9999999999999982, 0.0)]
#     753         >>> """
# --> 754         cl = self.cv.coords(item)
#     755         pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#     756         return  pl
#
# <string> in coords(self, *args, **kw)
#
# c:\users\acer\appdata\local\programs\python\python39\lib\tkinter\__init__.py in coords(self, *args)
#    2764         return [self.tk.getdouble(x) for x in
#    2765                            self.tk.splitlist(
# -> 2766                    self.tk.call((self._w, 'coords') + args))]
#    2767
#    2768     def _create(self, itemType, args, kw): # Args: (val, val, ..., cnf={})
#
# TclError: invalid command name ".!canvas"
