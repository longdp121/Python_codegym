# %%
import random
from random import randint
while True:
    my_list = ["Player", "Computer"]
    current_player = random.choice(my_list)
    print("New game!")
    print(f"Now is {current_player} turn.")
    print("_________________________________")
    result = None
    current_num = 0
    while True:
        if current_player == "Player":
            player_chose = int(input("Please choose 1, 2 or 3: "))
            while player_chose not in [1, 2, 3]:
                player_chose = int(input("Please choose 1, 2 or 3: "))
            current_num += player_chose
            print(f"{current_player} chose {player_chose}. The number is {current_num}")
            if current_num >= 21:
                result = "LOSE"
                print(f"{current_player} has reached {current_num}, you {result}")
                print("_________________________________")
                break
            else:
                current_player = "Computer"
        else:
            com_chose = randint(1,3)
            current_num += com_chose
            print(f"{current_player} chose {com_chose}. The number is {current_num}")
            if current_num >= 21:
                result = "WIN"
                print(f"{current_player} has reached {current_num}, you {result}")
                print("_________________________________")
                break
            else:
                current_player = "Player"
    if result == "LOSE":
        continue
    else:
        play_again = str(input("Do you want to play again? y/n: "))
        while play_again not in ["y", "n"]:
            play_again = str(input("Do you want to play again? y/n: "))
        if play_again == "y":
            continue
        else:
            break
print()
print("Game over!")
# Out:
# New game!
# Now is Computer turn.
# _________________________________
# Computer chose 1. The number is 1
# Please choose 1, 2 or 3: 3
# Player chose 3. The number is 4
# Computer chose 1. The number is 5
# Please choose 1, 2 or 3: 3
# Player chose 3. The number is 8
# Computer chose 2. The number is 10
# Please choose 1, 2 or 3: 3
# Player chose 3. The number is 13
# Computer chose 2. The number is 15
# Please choose 1, 2 or 3: 3
# Player chose 3. The number is 18
# Computer chose 3. The number is 21
# Computer has reached 21, you WIN
# _________________________________
# Do you want to play again? y/n: y
# New game!
# Now is Computer turn.
# _________________________________
# Computer chose 2. The number is 2
# Please choose 1, 2 or 3: 1
# Player chose 1. The number is 3
# Computer chose 2. The number is 5
# Please choose 1, 2 or 3: 1
# Player chose 1. The number is 6
# Computer chose 2. The number is 8
# Please choose 1, 2 or 3: 1
# Player chose 1. The number is 9
# Computer chose 2. The number is 11
# Please choose 1, 2 or 3: 1
# Player chose 1. The number is 12
# Computer chose 3. The number is 15
# Please choose 1, 2 or 3: 1
# Player chose 1. The number is 16
# Computer chose 2. The number is 18
# Please choose 1, 2 or 3: 1
# Player chose 1. The number is 19
# Computer chose 3. The number is 22
# Computer has reached 22, you WIN
# _________________________________
# Do you want to play again? y/n: n
#
# Game over!
